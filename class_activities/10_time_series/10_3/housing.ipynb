# %% [markdown]
# # House Regression

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
# Out:
# Bad key "text.kerning_factor" on line 4 in
# C:\Users\nospm\anaconda3\envs\pyvizenv\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %% [markdown]
# ### Read in Data

# %%
df = (
    pd.read_csv(Path("./data/USA_Housing.csv"))
    .set_index("Avg. Area Number of Rooms")
    .sort_index()
)
df.head()
# Out:
#                            Avg. Area Income  Avg. Area House Age  \
# Avg. Area Number of Rooms
# 3.236194                       74277.719901             6.987280
# 3.950225                       66961.664415             7.412989
# 3.950973                       60167.672607             4.590613
# 3.969632                       52868.323016             5.823226
# 4.027931                       53562.403541             6.323328
#
#                            Avg. Area Number of Bedrooms  Area Population  \
# Avg. Area Number of Rooms
# 3.236194                                           3.42     50233.790310
# 3.950225                                           2.31     33423.293292
# 3.950973                                           4.06     16811.303292
# 3.969632                                           4.38     41849.055084
# 4.027931                                           3.13     17964.469901
#
#                                   Price  \
# Avg. Area Number of Rooms
# 3.236194                   1.365081e+06
# 3.950225                   1.128720e+06
# 3.950973                   8.859177e+04
# 3.969632                   6.237216e+05
# 4.027931                   2.662989e+05
#
#                                                                      Address
# Avg. Area Number of Rooms
# 3.236194                   9835 Kimberly Street Suite 318\r\nMurphyview, ...
# 3.950225                   456 Gray Extension Suite 249\r\nJeremyville, M...
# 3.950973                        97009 Annette Vista\r\nMichaelside, AZ 39867
# 3.969632                   3669 Nichols Crossroad Apt. 092\r\nVegaburgh, ...
# 4.027931                   441 Ryan Courts Suite 717\r\nGonzalesport, NV ...

# %%
df.shape
# Out:
# (5000, 6)

# %% [markdown]
# ### Plot the Data

# %%
# Create a scatter plot of the data
plt.scatter(df.index, df.Price)

# %% [markdown]
# ## Create a SciKitLearn Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression

# %%
# Create a Linear Regression Model using sklearn
model = LinearRegression()
model
# Out:
# LinearRegression()

# %% [markdown]
# ## Fit the Model to the Data

# %%
# Separate the data into the X and y componenents
# In this case, y will be the `Price` and X will be the remainign columns
y = df[['Price']]
y.shape
# Out:
# (5000, 1)

# %%
# x = df[['Avg. Area Income','Avg. Area House Age','Avg. Area Number of Bedrooms','Area Population']].values.reshape(-1,1)
# x.shape
# x = df
# x.drop(columns['Avg. Area Income','Avg. Area House Age','Avg. Area Number of Bedrooms','Area Population'], inplace=True)
# x.head()

x = df.index.values.reshape(-1,1)
x
# Out:
# array([[ 3.23619402],
#        [ 3.95022469],
#        [ 3.95097265],
#        ...,
#        [10.21990198],
#        [10.28002242],
#        [10.75958834]])

# %%
# Fit the model to the data
model.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Make Predictions

# %%
# Make predictions using the X data
# YOUR CODE HERE!
# Out:
# array([ 789978.22263127,  874120.76535933,  874208.90683047, ...,
#        1612949.80474914, 1620034.49514083, 1676547.32853582])

# %%
# Plot X and y as a scatter plot
# Plot X and the predictions as a red line plot
# YOUR CODE HERE!

# %% [markdown]
# ### Extract the slope, intercept, and calculate the R2 score of the model

# %%
# Show the slope of the model
# YOUR CODE HERE!
# Out:
# array([117841.63757442])

# %%
# Show the intercept of the model
# YOUR CODE HERE!
# Out:
# 408619.81940216525

# %%
# Calculate the R2 Score
# YOUR CODE HERE!
# Out:
# 0.11267062525400562
